# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/live"

headers = {
	"x-rapidapi-key": "1b0e280e4dmshf40794f4f289c27p1311a4jsn0a577eeb6dd4",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers)
data=response.json()

# %%
data

# %%
match_options = []

for type_match in data.get("typeMatches", []):
    for series_match in type_match.get("seriesMatches", []):
        wrapper = series_match.get("seriesAdWrapper", {})
        for match in wrapper.get("matches", []):
            info = match.get("matchInfo")
            if info:
                # Store structural dictionaries for advanced back-end data tracking
                match_options.append({
                    "id": info["matchId"],
                    "display_name": f"{info['team1']['teamName']} vs {info['team2']['teamName']} ({info['matchDesc']})"
                })

# %%
match_options

# %%
info

# %%
data['typeMatches']

# %%
type_matches = data['typeMatches']
type_matches[0]

# %%
series_matches = type_matches[0]['seriesMatches']
print(series_matches[0].keys())

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/search"

querystring = {"plrN":"Tucker"}

headers = {
	"x-rapidapi-key": "1b0e280e4dmshf40794f4f289c27p1311a4jsn0a577eeb6dd4",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers, params=querystring)
data=response.json()

# %%
player_data = data['player']
player_data
# Out:
# [{'id': '673',
#   'name': 'Janeiro Tucker',
#   'teamName': 'Bermuda',
#   'faceImageId': 155599,
#   'dob': '1975-03-15'},
#  {'id': '674',
#   'name': 'Kwame Tucker',
#   'teamName': 'Bermuda',
#   'faceImageId': 155488,
#   'dob': '1976-09-28'},
#  {'id': '866',
#   'name': 'Tamauri Tucker',
#   'teamName': 'Bermuda',
#   'faceImageId': 155612,
#   'dob': '1988-12-10'},
#  {'id': '7240',
#   'name': 'Rod Tucker',
#   'teamName': 'Australia',
#   'faceImageId': 182026,
#   'dob': '1964-08-28'},
#  {'id': '11123',
#   'name': 'Fiachra Tucker',
#   'teamName': 'Ireland',
#   'faceImageId': 182026,
#   'dob': 'N/A'},
#  {'id': '11131',
#   'name': 'Lorcan Tucker',
#   'teamName': 'Ireland',
#   'faceImageId': 845647,
#   'dob': '1996-09-10'},
#  {'id': '26178',
#   'name': 'Delmi Tucker',
#   'teamName': 'South Africa',
#   'faceImageId': 255000,
#   'dob': '1997-03-05'},
#  {'id': '38265',
#   'name': 'Emily Tucker',
#   'teamName': 'Scotland',
#   'faceImageId': 182026,
# ...

# %%
target_id = None

# Loop and check condition
for player in player_data:
    if player['name'] == "Rod Tucker":
        target_id = player['id']
        break  # Exit the loop early once found

print(f"Rod Tucker's ID is: {target_id}")
# Out:
# Rod Tucker's ID is: 7240

# %%
import requests

url = f"https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/{target_id}"

headers = {
	"x-rapidapi-key": "1b0e280e4dmshf40794f4f289c27p1311a4jsn0a577eeb6dd4",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'id': '7240', 'bat': 'Left Handed Bat', 'bowl': 'Right-arm medium', 'name': 'Rod Tucker', 'fullName': 'Rodney James Tucker', 'role': 'Batsman', 'birthPlace': 'Auburn, Sydney, New South Wales', 'intlTeam': 'Australia', 'teams': 'New South Wales', 'DoB': 'August 28, 1964 (61 years)', 'image': 'http://i.cricketcb.com/stats/img/faceImages/7240.jpg', 'appIndex': {'seoTitle': 'Rod Tucker Profile - Cricbuzz | Cricbuzz.com', 'webURL': 'http://www.cricbuzz.com/profiles/7240/rod-tucker'}, 'DoBFormat': 'August 28, 1964', 'faceImageId': 182026, 'teamNameIds': [{'teamId': '104', 'teamName': 'New South Wales'}], 'playerTeamIds': '104', 'intlTeamImageId': 776202, 'recentBatting': {}, 'recentBowling': {}}

# %%
player_data[0]['id']
# Out:
# '673'
